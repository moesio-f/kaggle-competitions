# %% [markdown]
# # SVM

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

# %%
train = pd.read_parquet("../data/prototype/train.parquet")
stats = pd.read_parquet("../data/prototype/train_statistics.parquet")
validation = pd.read_parquet("../data/prototype/validation.parquet")

FEATURE_COLUMNS = [
    "Time_spent_Alone",
    "Social_event_attendance",
    "Going_outside",
    "Friends_circle_size",
    "Post_frequency",
]
TARGET_COLUMN = "Personality"
SEED = 42

# %%
# Default strategy for NaNs
for col in FEATURE_COLUMNS:
    validation[col] = validation[col].fillna(value=stats[col]["mean"])

# %%
X_train = train[FEATURE_COLUMNS].values
y_train = train[TARGET_COLUMN].values
X_test = validation[FEATURE_COLUMNS].values
y_test = validation[TARGET_COLUMN].values

# %%
results = []
for kernel in ["linear", "poly", "rbf", "sigmoid"]:
    for decision_function_shape in ["ovr", "ovo"]:
        for C in [1.0, 2.0, 3.0, 4.0]:
            model = SVC(
                kernel=kernel,
                decision_function_shape=decision_function_shape,
                C=C,
                random_state=SEED,
            )
            model.fit(X_train, y_train)
            preds = model.predict(X_test)
            results.append(
                {
                    "Kernel": kernel,
                    "Decision": decision_function_shape,
                    "C": C,
                    "Accuracy": accuracy_score(y_test, preds),
                }
            )
results = pd.DataFrame(results).sort_values("Accuracy", ascending=False)
results
# Out:
#      Kernel Decision    C  Accuracy
# 0    linear      ovr  1.0  0.970310
# 1    linear      ovr  2.0  0.970310
# 2    linear      ovr  3.0  0.970310
# 3    linear      ovr  4.0  0.970310
# 4    linear      ovo  1.0  0.970310
# 5    linear      ovo  2.0  0.970310
# 6    linear      ovo  3.0  0.970310
# 7    linear      ovo  4.0  0.970310
# 20      rbf      ovo  1.0  0.970310
# 16      rbf      ovr  1.0  0.970310
# 23      rbf      ovo  4.0  0.970040
# 22      rbf      ovo  3.0  0.970040
# 17      rbf      ovr  2.0  0.970040
# 18      rbf      ovr  3.0  0.970040
# 21      rbf      ovo  2.0  0.970040
# 19      rbf      ovr  4.0  0.970040
# 13     poly      ovo  2.0  0.968151
# 11     poly      ovr  4.0  0.968151
# 14     poly      ovo  3.0  0.968151
# 15     poly      ovo  4.0  0.968151
# 10     poly      ovr  3.0  0.968151
# 9      poly      ovr  2.0  0.968151
# 12     poly      ovo  1.0  0.967881
# 8      poly      ovr  1.0  0.967881
# 24  sigmoid      ovr  1.0  0.666937
# 28  sigmoid      ovo  1.0  0.666937
# 29  sigmoid      ovo  2.0  0.666667
# 25  sigmoid      ovr  2.0  0.666667
# 30  sigmoid      ovo  3.0  0.666397
# 26  sigmoid      ovr  3.0  0.666397
# 27  sigmoid      ovr  4.0  0.666127
# 31  sigmoid      ovo  4.0  0.666127
